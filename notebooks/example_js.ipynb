// %% [markdown]
// # NextGenDB - JavaScript/Node.js Quickstart
//
// This notebook demonstrates how to connect to NextGenDB using modern JavaScript (Fetch API).

// %%
const API_URL = 'http://localhost:8000/api/v1';

async function runQuery(query) {
  try {
    const response = await fetch(`${API_URL}/query`, {
      method: 'POST',
      headers: {
        'Content-Type': 'application/json',
      },
      body: JSON.stringify({ query })
    });
    
    if (!response.ok) {
      throw new Error(`HTTP error! status: ${response.status}`);
    }
    
    const data = await response.json();
    return data;
  } catch (e) {
    console.error('Failed to run query:', e);
  }
}

// %% [markdown]
// ### 1. Execute Cypher/SQL or Natural Language Query

// %%
// Example: Natural Language execution via Agent Planner
const result = await runQuery('Find anomalies in the system that affected Customer A');
console.log('Answer:', result.answer);
console.log('Confidence:', result.confidence);
console.log('Execution Steps:', result.steps);

// %% [markdown]
// ### 2. Fetch System Health and Metrics

// %%
async function getSystemStatus() {
  const res = await fetch(`${API_URL}/metrics/dashboard`);
  const data = await res.json();
  console.log('Graph Nodes:', data.metrics.graph_nodes);
  console.log('Memory Usage (MB):', data.metrics.memory_mb);
}

await getSystemStatus();
